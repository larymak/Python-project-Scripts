# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread("dog.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=768x480 at 0x7FC9D6B40950>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FC9D6ABE410>

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FC9D47F7E50>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=768x480 at 0x7FC9D48517D0>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=768x480 at 0x7FC9D47EF750>
# <PIL.Image.Image image mode=L size=768x480 at 0x7FC9D6AB6050>
